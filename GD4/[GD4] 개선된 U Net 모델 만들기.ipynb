# %% [markdown]
# <a href="https://colab.research.google.com/github/vkth7/Going-Deeper-CV-/blob/main/GD4/%5BGD4%5D%20%EA%B0%9C%EC%84%A0%EB%90%9C%20U%20Net%20%EB%AA%A8%EB%8D%B8%20%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -qq '/content/drive/MyDrive/aiffel/Going-Deeper/GD4/KITTI.zip'

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
  if is_train:    # 훈련용 데이터일 경우
    return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(              # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
  return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
dir_path = '/content/training'

augmentation_train = build_augmentation()
augmentation_test = build_augmentation(is_train=False)
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation_test(**image_data)
    processed = augmentation_train(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
  
plt.show()

# %%
class KittiGenerator(tf.keras.utils.Sequence):
  '''
  KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
  우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
  '''
  def __init__(self, 
               dir_path,
               batch_size=16,
               img_size=(224, 224, 3),
               output_size=(224, 224),
               is_train=True,
               augmentation=None):
    '''
    dir_path: dataset의 directory path입니다.
    batch_size: batch_size입니다.
    img_size: preprocess에 사용할 입력이미지의 크기입니다.
    output_size: ground_truth를 만들어주기 위한 크기입니다.
    is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
    augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
    '''
    self.dir_path = dir_path
    self.batch_size = batch_size
    self.is_train = is_train
    self.dir_path = dir_path
    self.augmentation = augmentation
    self.img_size = img_size
    self.output_size = output_size

    # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
    self.data = self.load_dataset()

  def load_dataset(self):
    # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
    # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
    input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
    label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]

    if self.is_train:
      return data[:-30]
    return data[-30:]
    
  def __len__(self):
    # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
    return math.ceil(len(self.data) / self.batch_size)

  def __getitem__(self, index):
    # 입력과 출력을 만듭니다.
    # 입력은 resize및 augmentation이 적용된 input image이고 
    # 출력은 semantic label입니다.
    batch_data = self.data[
                           index*self.batch_size:
                           (index + 1)*self.batch_size
                           ]
    inputs = np.zeros([self.batch_size, *self.img_size])
    outputs = np.zeros([self.batch_size, *self.output_size])
        
    for i, data in enumerate(batch_data):
      input_img_path, output_path = data
      _input = imread(input_img_path)
      _output = imread(output_path)
      _output = (_output==7).astype(np.uint8)*1
      data = {
          "image": _input,
          "mask": _output,
          }
      augmented = self.augmentation(**data)
      inputs[i] = augmented["image"]/255
      outputs[i] = augmented["mask"]
      return inputs, outputs

  def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
    self.indexes = np.arange(len(self.data))
    if self.is_train == True :
      np.random.shuffle(self.indexes)
      return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
unet_train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

unet_test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %%
unet_plus_plus_train_generator = KittiGenerator(
    dir_path, 
    batch_size=8,
    augmentation=augmentation,
)

unet_plus_plus_test_generator = KittiGenerator(
    dir_path, 
    batch_size=8,
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# # Unet 및 Unet++ 코드 작성
# - [깃 허브 참조](https://github.com/MrGiovanni/UNetPlusPlus/blob/master/keras/helper_functions.py)

# %%
nb_filters = [64,128,256,512, 1024]

# %%
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3, act='relu', dropout_rate=0.5):

    x = Conv2D(nb_filter, kernel_size, activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same')(input_tensor)
    x = Conv2D(nb_filter, kernel_size, activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same')(x)

    return x

# %%
def build_model_unet(input_shape=(224, 224, 3), nb_filter=nb_filters):
    model = None
    # TODO: input_shape에 따라 U-Net을 만들어주세요
    # 이때 model은 fully convolutional해야 합니다.
    inputs = Input(input_shape)

    conv1 = standard_unit(inputs, stage='1', nb_filter= nb_filters[0])
    pool1 = MaxPooling2D(pool_size=(2,2))(conv1)

    conv2 = standard_unit(pool1, stage='2', nb_filter= nb_filters[1])
    pool2 = MaxPooling2D(pool_size=(2,2))(conv2)

    conv3 = standard_unit(pool2, stage='3', nb_filter= nb_filters[2])
    pool3 = MaxPooling2D(pool_size=(2,2))(conv3)

    conv4 = standard_unit(pool3, stage='4', nb_filter=nb_filters[3])
    drop4 = Dropout(0.5)(conv4)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = standard_unit(pool4, stage='5', nb_filter=nb_filters[4])

    drop5 = Dropout(0.5)(conv5)
    
    up6 = Conv2DTranspose(nb_filters[3], 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv5)
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = standard_unit(merge6, stage='6', nb_filter=nb_filters[3])
    
    up7 = Conv2DTranspose(nb_filters[2], 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = standard_unit(merge7, stage='7', nb_filter=nb_filters[2])
    
    up8 = Conv2DTranspose(nb_filters[1], 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = standard_unit(merge8, stage='8', nb_filter=nb_filters[1])
    
    up9 = Conv2DTranspose(nb_filters[0], 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = standard_unit(merge9, stage='9', nb_filter=nb_filters[0]) 
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = Model(inputs = inputs, outputs = conv10)
    
    return model

# %%
def build_model_unet_plus_plus(input_shape=(224, 224, 3), nb_filter=nb_filters):
    model = None
    inputs = Input(input_shape)

    conv1_1 = standard_unit(inputs, stage='11', nb_filter=nb_filter[0])
    drop1 = Dropout(0.5)(conv1_1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(drop1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    drop2 = Dropout(0.5)(conv2_1)
    pool2 = MaxPooling2D(pool_size=(2, 2))(drop2)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12')
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    drop3 = Dropout(0.5)(conv3_1)
    pool3 = MaxPooling2D(pool_size=(2, 2))(drop3)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22')
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13')
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    drop4 = Dropout(0.5)(conv4_1)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32')
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23')
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14')
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])
    drop5 = Dropout(0.5)(conv5_1)

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(drop5)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42')
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33')
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24')
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15')
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])
    drop6 = Dropout(0.5)(conv1_5)

    outputs = Conv2D(1, 1, activation='sigmoid')(drop6)
    
    model = Model(inputs = inputs, outputs = outputs)
    
    return model

# %% [markdown]
# # model 생성 및 fit

# %% [markdown]
# ##unet

# %%
model_path_unet = '/content/seg_model_unet.h5'

model_unet = build_model_unet(nb_filter=nb_filters)
model_unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_1 (Conv2D)               (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv1_2 (Conv2D)               (None, 224, 224, 64  36928       ['conv1_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['conv1_2[0][0]']
#                                 )
#
#  conv2_1 (Conv2D)               (None, 112, 112, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2_2 (Conv2D)               (None, 112, 112, 12  147584      ['conv2_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['conv2_2[0][0]']
#
#  conv3_1 (Conv2D)               (None, 56, 56, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv3_2 (Conv2D)               (None, 56, 56, 256)  590080      ['conv3_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv3_2[0][0]']
#
#  conv4_1 (Conv2D)               (None, 28, 28, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv4_2 (Conv2D)               (None, 28, 28, 512)  2359808     ['conv4_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv4_2[0][0]']
#
#  conv5_1 (Conv2D)               (None, 14, 14, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv5_2 (Conv2D)               (None, 14, 14, 1024  9438208     ['conv5_1[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 512)  2097664    ['conv5_2[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 1024  0           ['conv4_2[0][0]',
#                                 )                                 'conv2d_transpose[0][0]']
#
#  conv6_1 (Conv2D)               (None, 28, 28, 512)  4719104     ['concatenate[0][0]']
#
#  conv6_2 (Conv2D)               (None, 28, 28, 512)  2359808     ['conv6_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 256)  524544     ['conv6_2[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 512)  0           ['conv3_2[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv7_1 (Conv2D)               (None, 56, 56, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv7_2 (Conv2D)               (None, 56, 56, 256)  590080      ['conv7_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 12  131200     ['conv7_2[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 25  0           ['conv2_2[0][0]',
#                                 6)                                'conv2d_transpose_2[0][0]']
#
#  conv8_1 (Conv2D)               (None, 112, 112, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv8_2 (Conv2D)               (None, 112, 112, 12  147584      ['conv8_1[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 64  32832      ['conv8_2[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 12  0           ['conv1_2[0][0]',
#                                 8)                                'conv2d_transpose_3[0][0]']
#
#  conv9_1 (Conv2D)               (None, 224, 224, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv9_2 (Conv2D)               (None, 224, 224, 64  36928       ['conv9_1[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 224, 224, 2)  1154        ['conv9_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 1)  3           ['conv2d[0][0]']
#
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_unet.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy')
model_unet.fit(
     unet_train_generator,
     validation_data=unet_test_generator,
     steps_per_epoch=len(unet_train_generator),
     epochs=100,
 )

#학습한 모델 저장
model_unet.save(model_path_unet)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 26s 635ms/step - loss: 0.6836 - val_loss: 0.6715
# Epoch 2/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.5275 - val_loss: 0.0749
# Epoch 3/100
# 11/11 [==============================] - 7s 598ms/step - loss: 0.0330 - val_loss: 0.0311
# Epoch 4/100
# 11/11 [==============================] - 7s 594ms/step - loss: 0.0345 - val_loss: 0.0308
# Epoch 5/100
# 11/11 [==============================] - 7s 595ms/step - loss: 0.0279 - val_loss: 0.0248
# Epoch 6/100
# 11/11 [==============================] - 7s 597ms/step - loss: 0.0288 - val_loss: 0.0259
# Epoch 7/100
# 11/11 [==============================] - 7s 602ms/step - loss: 0.0264 - val_loss: 0.0235
# Epoch 8/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.0247 - val_loss: 0.0249
# Epoch 9/100
# 11/11 [==============================] - 7s 610ms/step - loss: 0.0255 - val_loss: 0.0223
# Epoch 10/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0192 - val_loss: 0.0211
# Epoch 11/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0183 - val_loss: 0.0233
# Epoch 12/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0200 - val_loss: 0.0215
# Epoch 13/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.0214 - val_loss: 0.0804
# Epoch 14/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0291 - val_loss: 0.0242
# Epoch 15/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0310 - val_loss: 0.0263
# Epoch 16/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0246 - val_loss: 0.0218
# Epoch 17/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0195 - val_loss: 0.0205
# Epoch 18/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 19/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0194 - val_loss: 0.0222
# Epoch 20/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0211 - val_loss: 0.0488
# Epoch 21/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0267 - val_loss: 0.0231
# Epoch 22/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0186 - val_loss: 0.0217
# Epoch 23/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0154 - val_loss: 0.0234
# Epoch 24/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0171 - val_loss: 0.0199
# Epoch 25/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0202 - val_loss: 0.0213
# Epoch 26/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0210 - val_loss: 0.0232
# Epoch 27/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0194 - val_loss: 0.0199
# Epoch 28/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0164 - val_loss: 0.0203
# Epoch 29/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0172 - val_loss: 0.0202
# Epoch 30/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.0165 - val_loss: 0.0197
# Epoch 31/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0163 - val_loss: 0.0220
# Epoch 32/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0180 - val_loss: 0.0212
# Epoch 33/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0178 - val_loss: 0.0195
# Epoch 34/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0177 - val_loss: 0.0196
# Epoch 35/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0149 - val_loss: 0.0208
# Epoch 36/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.0166 - val_loss: 0.0196
# Epoch 37/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0152 - val_loss: 0.0202
# Epoch 38/100
# 11/11 [==============================] - 7s 610ms/step - loss: 0.0123 - val_loss: 0.0200
# Epoch 39/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0183 - val_loss: 0.0199
# Epoch 40/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.0175 - val_loss: 0.0217
# Epoch 41/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.0167 - val_loss: 0.0201
# Epoch 42/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0175 - val_loss: 0.0213
# Epoch 43/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0163 - val_loss: 0.0209
# Epoch 44/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0167 - val_loss: 0.0202
# Epoch 45/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0186 - val_loss: 0.0228
# Epoch 46/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0155 - val_loss: 0.0256
# Epoch 47/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0175 - val_loss: 0.0226
# Epoch 48/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0194 - val_loss: 0.0210
# Epoch 49/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0184 - val_loss: 0.0214
# Epoch 50/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0181 - val_loss: 0.0227
# Epoch 51/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0160 - val_loss: 0.0212
# Epoch 52/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0166 - val_loss: 0.0306
# Epoch 53/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0171 - val_loss: 0.0217
# Epoch 54/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0160 - val_loss: 0.0239
# Epoch 55/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0168 - val_loss: 0.0228
# Epoch 56/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0144 - val_loss: 0.0279
# Epoch 57/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0152 - val_loss: 0.0222
# Epoch 58/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0156 - val_loss: 0.0218
# Epoch 59/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0176 - val_loss: 0.0224
# Epoch 60/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0153 - val_loss: 0.0225
# Epoch 61/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0166 - val_loss: 0.0233
# Epoch 62/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0162 - val_loss: 0.0224
# Epoch 63/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0160 - val_loss: 0.0284
# Epoch 64/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0174 - val_loss: 0.0221
# Epoch 65/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0181 - val_loss: 0.0262
# Epoch 66/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0124 - val_loss: 0.0217
# Epoch 67/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0156 - val_loss: 0.0222
# Epoch 68/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0144 - val_loss: 0.0259
# Epoch 69/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0147 - val_loss: 0.0216
# Epoch 70/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0136 - val_loss: 0.0230
# Epoch 71/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0197 - val_loss: 0.0204
# Epoch 72/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0161 - val_loss: 0.0223
# Epoch 73/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0158 - val_loss: 0.0221
# Epoch 74/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0131 - val_loss: 0.0205
# Epoch 75/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0153 - val_loss: 0.0223
# Epoch 76/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0154 - val_loss: 0.0211
# Epoch 77/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0166 - val_loss: 0.0211
# Epoch 78/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0175 - val_loss: 0.0202
# Epoch 79/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0173 - val_loss: 0.0224
# Epoch 80/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0176 - val_loss: 0.0209
# Epoch 81/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0152 - val_loss: 0.0242
# Epoch 82/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0161 - val_loss: 0.0239
# Epoch 83/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0136 - val_loss: 0.0227
# Epoch 84/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0153 - val_loss: 0.0244
# Epoch 85/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0160 - val_loss: 0.0264
# Epoch 86/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0161 - val_loss: 0.0244
# Epoch 87/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0148 - val_loss: 0.0260
# Epoch 88/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0171 - val_loss: 0.0204
# Epoch 89/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0145 - val_loss: 0.0217
# Epoch 90/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0148 - val_loss: 0.0322
# Epoch 91/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0154 - val_loss: 0.0260
# Epoch 92/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0214 - val_loss: 0.0236
# Epoch 93/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0160 - val_loss: 0.0297
# Epoch 94/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0184 - val_loss: 0.0225
# Epoch 95/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.0217 - val_loss: 0.0213
# Epoch 96/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0191 - val_loss: 0.0215
# Epoch 97/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0192 - val_loss: 0.0215
# Epoch 98/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0155 - val_loss: 0.0230
# Epoch 99/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0157 - val_loss: 0.0212
# Epoch 100/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0156 - val_loss: 0.0222

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model_unet, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_unet_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.777609
# 0.7776087232154177

# %% [markdown]
# ## unet++

# %%
model_path_unet_plust_plus = '/content/seg_model_unet_plust_plus.h5'

model_unet_plust_plus=build_model_unet_plus_plus(nb_filter=nb_filters)
model_unet_plust_plus.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv11_1 (Conv2D)              (None, 224, 224, 64  1792        ['input_2[0][0]']
#                                 )
#
#  conv11_2 (Conv2D)              (None, 224, 224, 64  36928       ['conv11_1[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 224, 224, 64  0           ['conv11_2[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 112, 112, 64  0          ['dropout_2[0][0]']
#                                 )
#
#  conv21_1 (Conv2D)              (None, 112, 112, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  conv21_2 (Conv2D)              (None, 112, 112, 12  147584      ['conv21_1[0][0]']
#                                 8)
#
#  dropout_3 (Dropout)            (None, 112, 112, 12  0           ['conv21_2[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 128)  0          ['dropout_3[0][0]']
#
#  conv31_1 (Conv2D)              (None, 56, 56, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  conv31_2 (Conv2D)              (None, 56, 56, 256)  590080      ['conv31_1[0][0]']
#
#  dropout_4 (Dropout)            (None, 56, 56, 256)  0           ['conv31_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 256)  0          ['dropout_4[0][0]']
#
#  conv41_1 (Conv2D)              (None, 28, 28, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  conv41_2 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv41_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 28, 28, 512)  0           ['conv41_2[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['dropout_5[0][0]']
#
#  conv51_1 (Conv2D)              (None, 14, 14, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  conv51_2 (Conv2D)              (None, 14, 14, 1024  9438208     ['conv51_1[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 14, 14, 1024  0           ['conv51_2[0][0]']
#                                 )
#
#  up42 (Conv2DTranspose)         (None, 28, 28, 512)  2097664     ['dropout_6[0][0]']
#
#  merge42 (Concatenate)          (None, 28, 28, 1024  0           ['up42[0][0]',
#                                 )                                 'conv41_2[0][0]']
#
#  up32 (Conv2DTranspose)         (None, 56, 56, 256)  524544      ['conv41_2[0][0]']
#
#  conv42_1 (Conv2D)              (None, 28, 28, 512)  4719104     ['merge42[0][0]']
#
#  merge32 (Concatenate)          (None, 56, 56, 512)  0           ['up32[0][0]',
#                                                                   'conv31_2[0][0]']
#
#  up22 (Conv2DTranspose)         (None, 112, 112, 12  131200      ['conv31_2[0][0]']
#                                 8)
#
#  conv42_2 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv42_1[0][0]']
#
#  conv32_1 (Conv2D)              (None, 56, 56, 256)  1179904     ['merge32[0][0]']
#
#  merge22 (Concatenate)          (None, 112, 112, 25  0           ['up22[0][0]',
#                                 6)                                'conv21_2[0][0]']
#
#  up12 (Conv2DTranspose)         (None, 224, 224, 64  32832       ['conv21_2[0][0]']
#                                 )
#
#  up33 (Conv2DTranspose)         (None, 56, 56, 256)  524544      ['conv42_2[0][0]']
#
#  conv32_2 (Conv2D)              (None, 56, 56, 256)  590080      ['conv32_1[0][0]']
#
#  conv22_1 (Conv2D)              (None, 112, 112, 12  295040      ['merge22[0][0]']
#                                 8)
#
#  merge12 (Concatenate)          (None, 224, 224, 12  0           ['up12[0][0]',
#                                 8)                                'conv11_2[0][0]']
#
#  merge33 (Concatenate)          (None, 56, 56, 768)  0           ['up33[0][0]',
#                                                                   'conv31_2[0][0]',
#                                                                   'conv32_2[0][0]']
#
#  conv22_2 (Conv2D)              (None, 112, 112, 12  147584      ['conv22_1[0][0]']
#                                 8)
#
#  up23 (Conv2DTranspose)         (None, 112, 112, 12  131200      ['conv32_2[0][0]']
#                                 8)
#
#  conv12_1 (Conv2D)              (None, 224, 224, 64  73792       ['merge12[0][0]']
#                                 )
#
#  conv33_1 (Conv2D)              (None, 56, 56, 256)  1769728     ['merge33[0][0]']
#
#  merge23 (Concatenate)          (None, 112, 112, 38  0           ['up23[0][0]',
#                                 4)                                'conv21_2[0][0]',
#                                                                   'conv22_2[0][0]']
#
#  conv12_2 (Conv2D)              (None, 224, 224, 64  36928       ['conv12_1[0][0]']
#                                 )
#
#  up13 (Conv2DTranspose)         (None, 224, 224, 64  32832       ['conv22_2[0][0]']
#                                 )
#
#  conv33_2 (Conv2D)              (None, 56, 56, 256)  590080      ['conv33_1[0][0]']
#
#  conv23_1 (Conv2D)              (None, 112, 112, 12  442496      ['merge23[0][0]']
#                                 8)
#
#  merge13 (Concatenate)          (None, 224, 224, 19  0           ['up13[0][0]',
#                                 2)                                'conv11_2[0][0]',
#                                                                   'conv12_2[0][0]']
#
#  up24 (Conv2DTranspose)         (None, 112, 112, 12  131200      ['conv33_2[0][0]']
#                                 8)
#
#  conv23_2 (Conv2D)              (None, 112, 112, 12  147584      ['conv23_1[0][0]']
#                                 8)
#
#  conv13_1 (Conv2D)              (None, 224, 224, 64  110656      ['merge13[0][0]']
#                                 )
#
#  merge24 (Concatenate)          (None, 112, 112, 51  0           ['up24[0][0]',
#                                 2)                                'conv21_2[0][0]',
#                                                                   'conv22_2[0][0]',
#                                                                   'conv23_2[0][0]']
#
#  conv13_2 (Conv2D)              (None, 224, 224, 64  36928       ['conv13_1[0][0]']
#                                 )
#
#  up14 (Conv2DTranspose)         (None, 224, 224, 64  32832       ['conv23_2[0][0]']
#                                 )
#
#  conv24_1 (Conv2D)              (None, 112, 112, 12  589952      ['merge24[0][0]']
#                                 8)
#
#  merge14 (Concatenate)          (None, 224, 224, 25  0           ['up14[0][0]',
#                                 6)                                'conv11_2[0][0]',
#                                                                   'conv12_2[0][0]',
#                                                                   'conv13_2[0][0]']
#
#  conv24_2 (Conv2D)              (None, 112, 112, 12  147584      ['conv24_1[0][0]']
#                                 8)
#
#  conv14_1 (Conv2D)              (None, 224, 224, 64  147520      ['merge14[0][0]']
#                                 )
#
#  up15 (Conv2DTranspose)         (None, 224, 224, 64  32832       ['conv24_2[0][0]']
#                                 )
#
#  conv14_2 (Conv2D)              (None, 224, 224, 64  36928       ['conv14_1[0][0]']
#                                 )
#
#  merge15 (Concatenate)          (None, 224, 224, 32  0           ['up15[0][0]',
#                                 0)                                'conv11_2[0][0]',
#                                                                   'conv12_2[0][0]',
#                                                                   'conv13_2[0][0]',
#                                                                   'conv14_2[0][0]']
#
#  conv15_1 (Conv2D)              (None, 224, 224, 64  184384      ['merge15[0][0]']
#                                 )
#
#  conv15_2 (Conv2D)              (None, 224, 224, 64  36928       ['conv15_1[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 224, 224, 64  0           ['conv15_2[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 1)  65          ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 36,157,953
# Trainable params: 36,157,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_unet_plust_plus.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy')
model_unet_plust_plus.fit(
     unet_plus_plus_train_generator,
     validation_data=unet_plus_plus_test_generator,
     steps_per_epoch=len(unet_train_generator),
     epochs=100,
 )

#학습한 모델 저장
model_unet_plust_plus.save(model_path_unet_plust_plus)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 26s 1s/step - loss: 0.6837 - val_loss: 0.6603
# Epoch 2/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.5704 - val_loss: 0.4178
# Epoch 3/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0943 - val_loss: 0.0764
# Epoch 4/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0643 - val_loss: 0.0653
# Epoch 5/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0626 - val_loss: 0.0567
# Epoch 6/100
# 11/11 [==============================] - 11s 998ms/step - loss: 0.0800 - val_loss: 0.0772
# Epoch 7/100
# 11/11 [==============================] - 11s 999ms/step - loss: 0.0757 - val_loss: 0.0726
# Epoch 8/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.1153 - val_loss: 0.0784
# Epoch 9/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0750 - val_loss: 0.0736
# Epoch 10/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0692 - val_loss: 0.0670
# Epoch 11/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0649 - val_loss: 0.0611
# Epoch 12/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0510 - val_loss: 0.0547
# Epoch 13/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0642 - val_loss: 0.0628
# Epoch 14/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0650 - val_loss: 0.0627
# Epoch 15/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0484 - val_loss: 0.0608
# Epoch 16/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0474 - val_loss: 0.0602
# Epoch 17/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0584 - val_loss: 0.0528
# Epoch 18/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0618 - val_loss: 0.0554
# Epoch 19/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0592 - val_loss: 0.0549
# Epoch 20/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0471 - val_loss: 0.0515
# Epoch 21/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0543 - val_loss: 0.0493
# Epoch 22/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0434 - val_loss: 0.0518
# Epoch 23/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0525 - val_loss: 0.0535
# Epoch 24/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0610 - val_loss: 0.0534
# Epoch 25/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0621 - val_loss: 0.0514
# Epoch 26/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0578 - val_loss: 0.0528
# Epoch 27/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0573 - val_loss: 0.0530
# Epoch 28/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0564 - val_loss: 0.0498
# Epoch 29/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0498 - val_loss: 0.0515
# Epoch 30/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0455 - val_loss: 0.0516
# Epoch 31/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0387 - val_loss: 0.0493
# Epoch 32/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0384 - val_loss: 0.0486
# Epoch 33/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0430 - val_loss: 0.0509
# Epoch 34/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0368 - val_loss: 0.0537
# Epoch 35/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0417 - val_loss: 0.0516
# Epoch 36/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0435 - val_loss: 0.0536
# Epoch 37/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0511 - val_loss: 0.0533
# Epoch 38/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0483 - val_loss: 0.0493
# Epoch 39/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0395 - val_loss: 0.0474
# Epoch 40/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0463 - val_loss: 0.0503
# Epoch 41/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0392 - val_loss: 0.0505
# Epoch 42/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0454 - val_loss: 0.0484
# Epoch 43/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0409 - val_loss: 0.0472
# Epoch 44/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0308 - val_loss: 0.0486
# Epoch 45/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0412 - val_loss: 0.0463
# Epoch 46/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0370 - val_loss: 0.0473
# Epoch 47/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0310 - val_loss: 0.0420
# Epoch 48/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0200 - val_loss: 0.0377
# Epoch 49/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0270 - val_loss: 0.0404
# Epoch 50/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0296 - val_loss: 0.0481
# Epoch 51/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0310 - val_loss: 0.0412
# Epoch 52/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0303 - val_loss: 0.0404
# Epoch 53/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0254 - val_loss: 0.0372
# Epoch 54/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0198 - val_loss: 0.0309
# Epoch 55/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0292 - val_loss: 0.0312
# Epoch 56/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0327 - val_loss: 0.0379
# Epoch 57/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0307 - val_loss: 0.0508
# Epoch 58/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0333 - val_loss: 0.0383
# Epoch 59/100
# 11/11 [==============================] - 11s 991ms/step - loss: 0.0270 - val_loss: 0.0303
# Epoch 60/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0268 - val_loss: 0.0357
# Epoch 61/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0349 - val_loss: 0.0314
# Epoch 62/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0288 - val_loss: 0.0356
# Epoch 63/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0300 - val_loss: 0.0360
# Epoch 64/100
# 11/11 [==============================] - 11s 997ms/step - loss: 0.0273 - val_loss: 0.0420
# Epoch 65/100
# 11/11 [==============================] - 11s 995ms/step - loss: 0.0275 - val_loss: 0.0384
# Epoch 66/100
# 11/11 [==============================] - 11s 997ms/step - loss: 0.0280 - val_loss: 0.0460
# Epoch 67/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0326 - val_loss: 0.0318
# Epoch 68/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0392 - val_loss: 0.0352
# Epoch 69/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0358 - val_loss: 0.0425
# Epoch 70/100
# 11/11 [==============================] - 11s 1000ms/step - loss: 0.0382 - val_loss: 0.0447
# Epoch 71/100
# 11/11 [==============================] - 11s 998ms/step - loss: 0.0280 - val_loss: 0.0310
# Epoch 72/100
# 11/11 [==============================] - 11s 993ms/step - loss: 0.0309 - val_loss: 0.0331
# Epoch 73/100
# 11/11 [==============================] - 11s 996ms/step - loss: 0.0319 - val_loss: 0.0374
# Epoch 74/100
# 11/11 [==============================] - 11s 1000ms/step - loss: 0.0271 - val_loss: 0.0337
# Epoch 75/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0276 - val_loss: 0.0319
# Epoch 76/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0215 - val_loss: 0.0315
# Epoch 77/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0336 - val_loss: 0.0372
# Epoch 78/100
# 11/11 [==============================] - 11s 999ms/step - loss: 0.0271 - val_loss: 0.0359
# Epoch 79/100
# 11/11 [==============================] - 11s 999ms/step - loss: 0.0304 - val_loss: 0.0331
# Epoch 80/100
# 11/11 [==============================] - 11s 999ms/step - loss: 0.0265 - val_loss: 0.0320
# Epoch 81/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0256 - val_loss: 0.0332
# Epoch 82/100
# 11/11 [==============================] - 11s 1000ms/step - loss: 0.0209 - val_loss: 0.0292
# Epoch 83/100
# 11/11 [==============================] - 11s 1000ms/step - loss: 0.0197 - val_loss: 0.0265
# Epoch 84/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0196 - val_loss: 0.0280
# Epoch 85/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0161 - val_loss: 0.0295
# Epoch 86/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0246 - val_loss: 0.0341
# Epoch 87/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0264 - val_loss: 0.0371
# Epoch 88/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0216 - val_loss: 0.0376
# Epoch 89/100
# 11/11 [==============================] - 11s 1000ms/step - loss: 0.0256 - val_loss: 0.0359
# Epoch 90/100
# 11/11 [==============================] - 11s 998ms/step - loss: 0.0234 - val_loss: 0.0325
# Epoch 91/100
# 11/11 [==============================] - 11s 995ms/step - loss: 0.0203 - val_loss: 0.0331
# Epoch 92/100
# 11/11 [==============================] - 11s 997ms/step - loss: 0.0192 - val_loss: 0.0313
# Epoch 93/100
# 11/11 [==============================] - 11s 997ms/step - loss: 0.0257 - val_loss: 0.0310
# Epoch 94/100
# 11/11 [==============================] - 11s 997ms/step - loss: 0.0172 - val_loss: 0.0295
# Epoch 95/100
# 11/11 [==============================] - 11s 997ms/step - loss: 0.0289 - val_loss: 0.0331
# Epoch 96/100
# 11/11 [==============================] - 11s 998ms/step - loss: 0.0276 - val_loss: 0.0315
# Epoch 97/100
# 11/11 [==============================] - 11s 998ms/step - loss: 0.0217 - val_loss: 0.0283
# Epoch 98/100
# 11/11 [==============================] - 11s 999ms/step - loss: 0.0182 - val_loss: 0.0280
# Epoch 99/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0316 - val_loss: 0.0369
# Epoch 100/100
# 11/11 [==============================] - 11s 1s/step - loss: 0.0281 - val_loss: 0.0352

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model_unet_plust_plus, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_unet_plus_plus_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.741969
# 0.7419689119170985

# %% [markdown]
# U-net IoU : 0.777609
#
# U-net++ IoU : 0.741969
#
# U-net의 IoU가 더 높은 이유는 U-net++ 학습에서 loss 값이 너무 작게 나오는 것을 보아 overfitting이 일어난 것으로 추측됩니다.

# %% [markdown]
# #회고
# - 이번 프로젝트에서 어려웠던 점
#     - U-net과 U-net++를 학습시킨 결과물에서 IOU 값이 0으로 나오는 경우가 많았습니다.
#         - 코랩에서 컴퓨팅 리소스 값이 부족하다고 경고가 뜨는 것을 보아 두 가지 학습을 같이 돌려 너무 무거워서 그런게 아닐까 추측됩니다.
#     - get_output() 함수에서 output.show() 함수가 출력이 안됐습니다.
