# %% [markdown]
# <a href="https://colab.research.google.com/github/vkth7/Going-Deeper-CV-/blob/main/GD1/%5BGD1%5DResNet%20Ablation%20Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #0) 라이브러리 버전 확인하기
# ---
# <br>
#
# 사용할 라이브러리 버전을 둘러봅시다.

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import cv2
import glob
import os
import urllib3
urllib3.disable_warnings()

# %% [markdown]
# #1) ResNet 기본 블록 구성하기
# ---
# <br>
#
# 이제 실전으로 돌아와서 ResNet-34와 ResNet-50 네트워크를 직접 만든다고 생각해 봅시다. 우선 ResNet-34와 ResNet-50에서 사용되는 블록의 공통점을 찾고 차이점을 찾아봅시다.
# <br><br>
#
# - [Deep Residual Learning for Image Recognition(paper)](https://arxiv.org/pdf/1512.03385.pdf)
# - [빛과 같은 카이밍허님의 깃헙](https://github.com/KaimingHe/deep-residual-networks)
#
# <br>
#
# ![](https://d3s0tskafalll9.cloudfront.net/media/images/GC-1-P-table1.max-800x600.png)
#
# **Q1. ResNet논문에 소개된 위 표에서, ResNet 34와 50에서 사용된 블록들의 공통점과 차이점을 비교해보고 그 특징을 정리해봅시다.**
#
# - ResNet-34와 ResNet-50은 모두 conv block이라고 불리는 블록 구조를 각각 3, 4, 6, 3개씩 반복해서 쌓은 형태라는 공통점을 가지고 있습니다. 그러나 ResNet-34와 ResNet-50의 블록 내부 구성은 약간 다릅니다. ResNet-34의 경우 Block은 3x3 kernel인 Convolution layer로만 구성되어있지만, ResNet-50은 1x1 Convolution이 앞뒤로 붙어 더 많은 레이어를 한 블록 내에 가지게 됩니다.
#
# <br>
#
# 위의 퀴즈의 답을 어느 정도 스스로 찾아내셨다면 ResNet의 기본 블록, 또는 Residual 블록(residual block)이 어떻게 구성되어야 할지 감이 오셨을 것입니다. Learning by Doing 이라고 하죠! 이번에는 ResNet의 블록을 직접 만들어 봅시다! 혹시나 모델 내의 앞과 뒤에서 반복되지 않을 것 같은 부분은 함수로 구현하지 않아도 됩니다.
# <br><br>
# 우리가 지금 만들어야 하는 것은 블록을 생성하는 함수입니다. 처음이라 너무 막연하실 수 있겠지만 여러분들은 이미 몇 번의 경험이 있습니다.
# 일단은 VGG에서도 블록을 생성하는 함수를 만들었습니다. ResNet이라 하더라도 아이디어의 기본 원리는 다르지 않습니다.
# <br><br>
# 그리고, 여러분들은 아마 이전에 VGG-16이나 ResNet-50 모델을 만들어서 훈련까지 시켜본 경험들이 있으실 것입니다. 코드를 스스로 구현한 것이 아니라 공개된 오픈소스를 활용해서 빠르게 구성했겠지만, 블록 생성 함수가 어떤 형태로 만들어지는지를 이미 경험해 보신 바 있을 테니 그것을 참고하셔도 도움이 될 것입니다.
# <br><br>
# 하지만 이번 단계에서는 가급적 ResNet 논문을 통해서 구현 방법에 대한 정보를 얻으시기를 권합니다. 논문만 보고 스스로 구현해 보는 경험을 통해 딥러닝 개발자로서의 내공과 자신감이 다져지게 될 것입니다.

# %% [markdown]
# #2) ResNet-34, ResNet-50 Complete Model
# ---
# <br>
#
# ><br>
# >
# >ResNet 모델 구현 시 Sequential API나 Subclass API를 사용한다면, 그 과정에서 모델 단위로 기존의 코드를 재활용했을 때 model.summary() 호출 시 서브모델 내부의 레이어 구성이 생략되고 서브모델 단위로만 출력될 우려가 있습니다. 모델 구성만을 위해서는 그런 방법도 무방하지만, 가급적 이번 실습에서는 VGG 실습 예시에서처럼 Functional API 를 구성하는 방식을 사용할 것을 권합니다.
# ><br><br>

# %% [markdown]
# ##ResNet-34
#
# VGG와 같이 블록을 만드는 함수를 사용해서 직접 전체 모델을 만들어 봅시다. ResNet-34와 ResNet-50의 차이에 따라 달라지는 구성(configuration)을 함수에 전달해서 같은 생성 함수 build_resnet()를 통해서 ResNet의 여러 가지 버전들을 모두 만들어 낼 수 있도록 해야 합니다.

# %%
# function for building ResNet Block

def build_resnet_block(input_layer,
                       num_cnn=3, 
                       channel=64,
                       block_num=0,
                       is_50=False
                       ):
    # 입력 레이어
    x = input_layer

    input = input_layer

    if not is_50:
        # ResNet-34
        for cnn_num in range(num_cnn):
            if block_num == 0:
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    kernel_initializer='he_normal',
                    padding='same',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)


            elif cnn_num == 0:
                input = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    strides=(2,2),
                    padding='same',
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{0}'
                    )(input)

                input = layers.BatchNormalization()(input)


                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    strides=2,
                    padding='same',
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            else:
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    kernel_initializer='he_normal',
                    padding='same',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            x = layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}_2'
                )(x)

            x = layers.BatchNormalization()(x)

            if cnn_num==0:
                x = layers.Add()([input, x])

            else:
                x = layers.Add()([output, x])

            x = layers.Activation('relu')(x)

            output = x

    else:
        # ResNet-50
        for cnn_num in range(num_cnn):

            if block_num==0 and cnn_num==0:
                
                input = layers.Conv2D(
                    filters=4*channel,
                    kernel_size=(1,1),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{0}'
                    )(input)

                input = layers.BatchNormalization()(input)

                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            elif cnn_num==0:

                input = layers.Conv2D(
                    filters=4*channel,
                    kernel_size=(1,1),
                    strides=(2,2),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{0}'
                    )(input)

                input = layers.BatchNormalization()(input)

                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    strides=(2,2),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            else:
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)            

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            x = layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}_2'
                )(x)

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            x = layers.Conv2D(
                filters=4*channel,
                kernel_size=(1,1),
                kernel_initializer='he_normal',
                name=f'block{block_num}_conv{cnn_num}_3'
                )(x)
            
            x = layers.BatchNormalization()(x)

            if cnn_num==0:
                x = layers.Add()([input, x])

            else:
                x = layers.Add()([output, x])

            x = layers.Activation('relu')(x)

            output = x

    return output

# %%
def build_resnet(input_shape=(224,224,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=2,
                 is_50=False):

    # input layer
    input_layer = layers.Input(shape=input_shape)

    output = input_layer
    # Conv2D layer
    output = layers.Conv2D(filters=64,
                      kernel_size=(7,7),
                      strides=2,
                      kernel_initializer='he_normal',
                      padding='same',
                      )(output)

    output = layers.BatchNormalization()(output)

    output = layers.Activation('relu')(output)

    # Max Pooling layer
    output = keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=2,
    )(output)

    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):

        output = build_resnet_block(output,
                                    num_cnn=num_cnn, 
                                    channel=channel,
                                    block_num=i,
                                    is_50=is_50
                                    )
    
    output = layers.GlobalAveragePooling2D()(output)

    output = layers.Dense(num_classes,
                          activation='softmax',
                          name='predictions'
                          )(output)

    model = keras.Model(inputs=input_layer,
                        outputs=output
                        )
    return model

# %%
resnet_34 = build_resnet(input_shape=(32, 32, 3), is_50=False)
resnet_34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 16, 16, 64)   9472        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['activation[0][0]']
#
#  block0_conv0_1 (Conv2D)        (None, 8, 8, 64)     36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv0_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_1[0][0]']
#
#  block0_conv0_2 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv0_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['add[0][0]']
#
#  block0_conv1_1 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv1_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_3[0][0]']
#
#  block0_conv1_2 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv1_2[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  block0_conv2_1 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv2_1[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_5[0][0]']
#
#  block0_conv2_2 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv2_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 64)     0           ['add_2[0][0]']
#
#  block1_conv0_1 (Conv2D)        (None, 4, 4, 128)    73856       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv0_1[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 4, 4, 128)    0           ['batch_normalization_8[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 4, 4, 128)    8320        ['activation_6[0][0]']
#
#  block1_conv0_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv0[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv0_2[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_8 (Activation)      (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  block1_conv1_1 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 4, 128)   512         ['block1_conv1_1[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 4, 4, 128)    0           ['batch_normalization_10[0][0]']
#
#  block1_conv1_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 4, 128)   512         ['block1_conv1_2[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 4, 4, 128)    0           ['activation_8[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_10 (Activation)     (None, 4, 4, 128)    0           ['add_4[0][0]']
#
#  block1_conv2_1 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 128)   512         ['block1_conv2_1[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_12[0][0]']
#
#  block1_conv2_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 4, 4, 128)   512         ['block1_conv2_2[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['activation_10[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  activation_12 (Activation)     (None, 4, 4, 128)    0           ['add_5[0][0]']
#
#  block1_conv3_1 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 128)   512         ['block1_conv3_1[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_14[0][0]']
#
#  block1_conv3_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 128)   512         ['block1_conv3_2[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['activation_12[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['add_6[0][0]']
#
#  block2_conv0_1 (Conv2D)        (None, 2, 2, 256)    295168      ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv0_1[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_17[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 2, 2, 256)    33024       ['activation_14[0][0]']
#
#  block2_conv0_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv0[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv0_2[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_16 (Activation)     (None, 2, 2, 256)    0           ['add_7[0][0]']
#
#  block2_conv1_1 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv1_1[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_19[0][0]']
#
#  block2_conv1_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv1_2[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 2, 2, 256)    0           ['activation_16[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_18 (Activation)     (None, 2, 2, 256)    0           ['add_8[0][0]']
#
#  block2_conv2_1 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv2_1[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_21[0][0]']
#
#  block2_conv2_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv2_2[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['activation_18[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_20 (Activation)     (None, 2, 2, 256)    0           ['add_9[0][0]']
#
#  block2_conv3_1 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv3_1[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_23[0][0]']
#
#  block2_conv3_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv3_2[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['activation_20[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['add_10[0][0]']
#
#  block2_conv4_1 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv4_1[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_25[0][0]']
#
#  block2_conv4_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv4_2[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['activation_22[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_24 (Activation)     (None, 2, 2, 256)    0           ['add_11[0][0]']
#
#  block2_conv5_1 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv5_1[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_27[0][0]']
#
#  block2_conv5_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv5_2[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['activation_24[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['add_12[0][0]']
#
#  block3_conv0_1 (Conv2D)        (None, 1, 1, 512)    1180160     ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv0_1[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_30[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 1, 1, 512)    131584      ['activation_26[0][0]']
#
#  block3_conv0_2 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_27[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv0[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv0_2[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_29[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_28 (Activation)     (None, 1, 1, 512)    0           ['add_13[0][0]']
#
#  block3_conv1_1 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv1_1[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_32[0][0]']
#
#  block3_conv1_2 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_29[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv1_2[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['activation_28[0][0]',
#                                                                   'batch_normalization_33[0][0]']
#
#  activation_30 (Activation)     (None, 1, 1, 512)    0           ['add_14[0][0]']
#
#  block3_conv2_1 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv2_1[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_34[0][0]']
#
#  block3_conv2_2 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv2_2[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['activation_30[0][0]',
#                                                                   'batch_normalization_35[0][0]']
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_32[0][0]']
#  alAveragePooling2D)
#
#  predictions (Dense)            (None, 2)            1026        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,311,234
# Trainable params: 21,294,210
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %% [markdown]
# ##ResNet-50
#
# 위에서 만든 함수에 config를 조절해서 ResNet-50을 만들어 봅니다. 구조가 원하는 대로 만들어졌는지 확인하고 이상이 있다면 수정합니다.

# %%
resnet_50 = build_resnet(input_shape=(32, 32,3), is_50=True)
resnet_50.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   9472        ['input_2[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 64)  256         ['conv2d_1[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_36[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_33[0][0]']
#
#  block0_conv0_1 (Conv2D)        (None, 8, 8, 64)     4160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 64)    256         ['block0_conv0_1[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_38[0][0]']
#
#  block0_conv0_2 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 64)    256         ['block0_conv0_2[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_39[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 8, 8, 256)    16640       ['max_pooling2d_1[0][0]']
#
#  block0_conv0_3 (Conv2D)        (None, 8, 8, 256)    16640       ['activation_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 256)   1024        ['block0_conv0[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 256)   1024        ['block0_conv0_3[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_37[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 256)    0           ['add_16[0][0]']
#
#  block0_conv1_1 (Conv2D)        (None, 8, 8, 64)     16448       ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 64)    256         ['block0_conv1_1[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_41[0][0]']
#
#  block0_conv1_2 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_37[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 64)    256         ['block0_conv1_2[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_42[0][0]']
#
#  block0_conv1_3 (Conv2D)        (None, 8, 8, 256)    16640       ['activation_38[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 256)   1024        ['block0_conv1_3[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 8, 8, 256)    0           ['activation_36[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 256)    0           ['add_17[0][0]']
#
#  block0_conv2_1 (Conv2D)        (None, 8, 8, 64)     16448       ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['block0_conv2_1[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_44[0][0]']
#
#  block0_conv2_2 (Conv2D)        (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 64)    256         ['block0_conv2_2[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_45[0][0]']
#
#  block0_conv2_3 (Conv2D)        (None, 8, 8, 256)    16640       ['activation_41[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 256)   1024        ['block0_conv2_3[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 256)    0           ['activation_39[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 256)    0           ['add_18[0][0]']
#
#  block1_conv0_1 (Conv2D)        (None, 4, 4, 128)    32896       ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 4, 4, 128)   512         ['block1_conv0_1[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_48[0][0]']
#
#  block1_conv0_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 4, 4, 128)   512         ['block1_conv0_2[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_49[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 4, 4, 512)    131584      ['activation_42[0][0]']
#
#  block1_conv0_3 (Conv2D)        (None, 4, 4, 512)    66048       ['activation_44[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 4, 4, 512)   2048        ['block1_conv0[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 4, 4, 512)   2048        ['block1_conv0_3[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_47[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  activation_45 (Activation)     (None, 4, 4, 512)    0           ['add_19[0][0]']
#
#  block1_conv1_1 (Conv2D)        (None, 4, 4, 128)    65664       ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 4, 4, 128)   512         ['block1_conv1_1[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_51[0][0]']
#
#  block1_conv1_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_46[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 4, 4, 128)   512         ['block1_conv1_2[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_52[0][0]']
#
#  block1_conv1_3 (Conv2D)        (None, 4, 4, 512)    66048       ['activation_47[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 4, 4, 512)   2048        ['block1_conv1_3[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 4, 4, 512)    0           ['activation_45[0][0]',
#                                                                   'batch_normalization_53[0][0]']
#
#  activation_48 (Activation)     (None, 4, 4, 512)    0           ['add_20[0][0]']
#
#  block1_conv2_1 (Conv2D)        (None, 4, 4, 128)    65664       ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 4, 4, 128)   512         ['block1_conv2_1[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_54[0][0]']
#
#  block1_conv2_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_49[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 4, 4, 128)   512         ['block1_conv2_2[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_55[0][0]']
#
#  block1_conv2_3 (Conv2D)        (None, 4, 4, 512)    66048       ['activation_50[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 4, 4, 512)   2048        ['block1_conv2_3[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 4, 4, 512)    0           ['activation_48[0][0]',
#                                                                   'batch_normalization_56[0][0]']
#
#  activation_51 (Activation)     (None, 4, 4, 512)    0           ['add_21[0][0]']
#
#  block1_conv3_1 (Conv2D)        (None, 4, 4, 128)    65664       ['activation_51[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 4, 4, 128)   512         ['block1_conv3_1[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_57[0][0]']
#
#  block1_conv3_2 (Conv2D)        (None, 4, 4, 128)    147584      ['activation_52[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 4, 4, 128)   512         ['block1_conv3_2[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_58[0][0]']
#
#  block1_conv3_3 (Conv2D)        (None, 4, 4, 512)    66048       ['activation_53[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 4, 4, 512)   2048        ['block1_conv3_3[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 4, 4, 512)    0           ['activation_51[0][0]',
#                                                                   'batch_normalization_59[0][0]']
#
#  activation_54 (Activation)     (None, 4, 4, 512)    0           ['add_22[0][0]']
#
#  block2_conv0_1 (Conv2D)        (None, 2, 2, 256)    131328      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv0_1[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_61[0][0]']
#
#  block2_conv0_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv0_2[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_62[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 2, 2, 1024)   525312      ['activation_54[0][0]']
#
#  block2_conv0_3 (Conv2D)        (None, 2, 2, 1024)   263168      ['activation_56[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv0[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv0_3[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 2, 2, 1024)   0           ['batch_normalization_60[0][0]',
#                                                                   'batch_normalization_63[0][0]']
#
#  activation_57 (Activation)     (None, 2, 2, 1024)   0           ['add_23[0][0]']
#
#  block2_conv1_1 (Conv2D)        (None, 2, 2, 256)    262400      ['activation_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv1_1[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_64[0][0]']
#
#  block2_conv1_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv1_2[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_65[0][0]']
#
#  block2_conv1_3 (Conv2D)        (None, 2, 2, 1024)   263168      ['activation_59[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv1_3[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 2, 2, 1024)   0           ['activation_57[0][0]',
#                                                                   'batch_normalization_66[0][0]']
#
#  activation_60 (Activation)     (None, 2, 2, 1024)   0           ['add_24[0][0]']
#
#  block2_conv2_1 (Conv2D)        (None, 2, 2, 256)    262400      ['activation_60[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv2_1[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_67[0][0]']
#
#  block2_conv2_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_61[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv2_2[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_68[0][0]']
#
#  block2_conv2_3 (Conv2D)        (None, 2, 2, 1024)   263168      ['activation_62[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv2_3[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 2, 2, 1024)   0           ['activation_60[0][0]',
#                                                                   'batch_normalization_69[0][0]']
#
#  activation_63 (Activation)     (None, 2, 2, 1024)   0           ['add_25[0][0]']
#
#  block2_conv3_1 (Conv2D)        (None, 2, 2, 256)    262400      ['activation_63[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv3_1[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_70[0][0]']
#
#  block2_conv3_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_64[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv3_2[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_71[0][0]']
#
#  block2_conv3_3 (Conv2D)        (None, 2, 2, 1024)   263168      ['activation_65[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv3_3[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 2, 2, 1024)   0           ['activation_63[0][0]',
#                                                                   'batch_normalization_72[0][0]']
#
#  activation_66 (Activation)     (None, 2, 2, 1024)   0           ['add_26[0][0]']
#
#  block2_conv4_1 (Conv2D)        (None, 2, 2, 256)    262400      ['activation_66[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv4_1[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_73[0][0]']
#
#  block2_conv4_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_67[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv4_2[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_74[0][0]']
#
#  block2_conv4_3 (Conv2D)        (None, 2, 2, 1024)   263168      ['activation_68[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv4_3[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 2, 2, 1024)   0           ['activation_66[0][0]',
#                                                                   'batch_normalization_75[0][0]']
#
#  activation_69 (Activation)     (None, 2, 2, 1024)   0           ['add_27[0][0]']
#
#  block2_conv5_1 (Conv2D)        (None, 2, 2, 256)    262400      ['activation_69[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv5_1[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_76[0][0]']
#
#  block2_conv5_2 (Conv2D)        (None, 2, 2, 256)    590080      ['activation_70[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv5_2[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_77[0][0]']
#
#  block2_conv5_3 (Conv2D)        (None, 2, 2, 1024)   263168      ['activation_71[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 2, 2, 1024)  4096        ['block2_conv5_3[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 2, 2, 1024)   0           ['activation_69[0][0]',
#                                                                   'batch_normalization_78[0][0]']
#
#  activation_72 (Activation)     (None, 2, 2, 1024)   0           ['add_28[0][0]']
#
#  block3_conv0_1 (Conv2D)        (None, 1, 1, 512)    524800      ['activation_72[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv0_1[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_80[0][0]']
#
#  block3_conv0_2 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_73[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv0_2[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_81[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 1, 1, 2048)   2099200     ['activation_72[0][0]']
#
#  block3_conv0_3 (Conv2D)        (None, 1, 1, 2048)   1050624     ['activation_74[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 1, 1, 2048)  8192        ['block3_conv0[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 1, 1, 2048)  8192        ['block3_conv0_3[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_79[0][0]',
#                                                                   'batch_normalization_82[0][0]']
#
#  activation_75 (Activation)     (None, 1, 1, 2048)   0           ['add_29[0][0]']
#
#  block3_conv1_1 (Conv2D)        (None, 1, 1, 512)    1049088     ['activation_75[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv1_1[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_83[0][0]']
#
#  block3_conv1_2 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_76[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv1_2[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_84[0][0]']
#
#  block3_conv1_3 (Conv2D)        (None, 1, 1, 2048)   1050624     ['activation_77[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 1, 1, 2048)  8192        ['block3_conv1_3[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 1, 1, 2048)   0           ['activation_75[0][0]',
#                                                                   'batch_normalization_85[0][0]']
#
#  activation_78 (Activation)     (None, 1, 1, 2048)   0           ['add_30[0][0]']
#
#  block3_conv2_1 (Conv2D)        (None, 1, 1, 512)    1049088     ['activation_78[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv2_1[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_86[0][0]']
#
#  block3_conv2_2 (Conv2D)        (None, 1, 1, 512)    2359808     ['activation_79[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv2_2[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_87[0][0]']
#
#  block3_conv2_3 (Conv2D)        (None, 1, 1, 2048)   1050624     ['activation_80[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 1, 1, 2048)  8192        ['block3_conv2_3[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 1, 1, 2048)   0           ['activation_78[0][0]',
#                                                                   'batch_normalization_88[0][0]']
#
#  activation_81 (Activation)     (None, 1, 1, 2048)   0           ['add_31[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['activation_81[0][0]']
#  obalAveragePooling2D)
#
#  predictions (Dense)            (None, 2)            4098        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ResNet-50은 구현마다 약간씩 다르게 나올 수 있습니다. 왜냐하면 Residual 블록의 Batch Normalization과 ReLU 레이어의 위치가 논문에 명시되지 않았기 때문이죠!
# <br><br>
# 하지만 ResNet을 고안한 4인방은 이에 대해 또 한번 논문을 씁니다. Residual 블록에 대해서 자세하게 씁니다. 이 논문을 읽어보면 오리지널 ResNet-50에 대한 힌트가 약.간. 있을 수도 있습니다~!
# <br><br>
#
# - [Identity Mappings in Deep Residual Networks](https://arxiv.org/pdf/1603.05027.pdf)

# %% [markdown]
# #3) 일반 네트워크(plain network) 만들기
# ---
# <br>
#
# 블록 코드 수정하기
# <br><br>
# 우리는 앞에서 ResNet 모델을 구현했습니다. ResNet의 핵심 아이디어는 skip connection과 residual network기 때문에, ResNet의 효과를 보여주기 위해서는 skip connection이 없는 일반 네트워크(plain net)가 필요합니다. 위에서 ResNet 블록을 만들기 위한 함수를 그대로 활용해서 skip connection이 없는 블록을 만들 수 있도록 기능을 추가해 주세요!
# <br><br><br>
# 전체 함수 코드 수정하기
# <br><br>
# 이제 위에서 만든 블록 함수를 토대로 전체 네트워크를 만들 수 있도록 전체 네트워크 코드를 수정합시다. ResNet-50과 ResNet-34, 그리고 같은 레이어를 가지지만 skip connection이 없는 PlainNet-50과 PlainNet-34를 만들 수 있는 함수 ```build_plainnet()```를 만들어 보세요. 이때 입력 이미지의 크기는 ```(224, 224, 3)```으로 해주세요.

# %%
# function for building ResNet Block

def build_resnet_block(input_layer,
                       num_cnn=3, 
                       channel=64,
                       block_num=0,
                       is_50=False
                       ):
    # 입력 레이어
    x = input_layer

    if not is_50:
        # PlainNet-34
        for cnn_num in range(num_cnn):
            if block_num == 0:
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    kernel_initializer='he_normal',
                    padding='same',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)


            elif cnn_num == 0:
                
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    strides=2,
                    padding='same',
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            else:
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    kernel_initializer='he_normal',
                    padding='same',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            x = layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}_2'
                )(x)

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            output = x

    else:
        # PlainNet-50
        for cnn_num in range(num_cnn):

            if block_num==0:
                
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            elif cnn_num==0:

                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    strides=(2,2),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)

            else:
                x = layers.Conv2D(
                    filters=channel,
                    kernel_size=(1,1),
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                    )(x)            

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            x = layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}_2'
                )(x)

            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            x = layers.Conv2D(
                filters=4*channel,
                kernel_size=(1,1),
                kernel_initializer='he_normal',
                name=f'block{block_num}_conv{cnn_num}_3'
                )(x)
            
            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)

            output = x

    return output

# %%
def build_plainnet(input_shape=(224,224,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=10,
                 is_50=False):

    # input layer
    input_layer = layers.Input(shape=input_shape)

    output = input_layer
    # Conv2D layer
    output = layers.Conv2D(filters=64,
                      kernel_size=(7,7),
                      strides=2,
                      kernel_initializer='he_normal',
                      padding='same',
                      )(output)

    output = layers.BatchNormalization()(output)

    output = layers.Activation('relu')(output)

    # Max Pooling layer
    output = keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=2,
    )(output)

    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):

        output = build_resnet_block(output,
                                    num_cnn=num_cnn, 
                                    channel=channel,
                                    block_num=i,
                                    is_50=is_50
                                    )
    
    output = layers.GlobalAveragePooling2D()(output)

    output = layers.Dense(num_classes,
                          activation='softmax',
                          name='predictions'
                          )(output)

    model = keras.Model(inputs=input_layer,
                        outputs=output
                        )
    return model

# %%
plain_34 = build_plainnet(input_shape=(32, 32, 3), is_50=False)
plain_34.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        9472
#
#  batch_normalization_89 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  activation_82 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  block0_conv0_1 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_90 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_83 (Activation)  (None, 8, 8, 64)          0
#
#  block0_conv0_2 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_91 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_84 (Activation)  (None, 8, 8, 64)          0
#
#  block0_conv1_1 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_92 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_85 (Activation)  (None, 8, 8, 64)          0
#
#  block0_conv1_2 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_93 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_86 (Activation)  (None, 8, 8, 64)          0
#
#  block0_conv2_1 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_94 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_87 (Activation)  (None, 8, 8, 64)          0
#
#  block0_conv2_2 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_95 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_88 (Activation)  (None, 8, 8, 64)          0
#
#  block1_conv0_1 (Conv2D)     (None, 4, 4, 128)         73856
#
#  batch_normalization_96 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_89 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv0_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_97 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_90 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv1_1 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_98 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_91 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv1_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_99 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_92 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv2_1 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_100 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv2_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_101 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv3_1 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_102 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 4, 4, 128)         0
#
#  block1_conv3_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_103 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 4, 4, 128)         0
#
#  block2_conv0_1 (Conv2D)     (None, 2, 2, 256)         295168
#
#  batch_normalization_104 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 2, 2, 256)         0
#
#  block2_conv0_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_105 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 2, 2, 256)         0
#
#  block2_conv1_1 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_106 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_99 (Activation)  (None, 2, 2, 256)         0
#
#  block2_conv1_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_107 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_100 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv2_1 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_108 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_101 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv2_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_109 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_102 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv3_1 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_110 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_103 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv3_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_111 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_104 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv4_1 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_112 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_105 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv4_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_113 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_106 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv5_1 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_114 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_107 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv5_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_115 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_108 (Activation)  (None, 2, 2, 256)        0
#
#  block3_conv0_1 (Conv2D)     (None, 1, 1, 512)         1180160
#
#  batch_normalization_116 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_109 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv0_2 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_117 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_110 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv1_1 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_118 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_111 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv1_2 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_119 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_112 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv2_1 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_120 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_113 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv2_2 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_121 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_114 (Activation)  (None, 1, 1, 512)        0
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 21,138,826
# Trainable params: 21,123,594
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
plain_50 = build_plainnet(input_shape=(32, 32, 3), is_50=True)
plain_50.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        9472
#
#  batch_normalization_122 (Ba  (None, 16, 16, 64)       256
#  tchNormalization)
#
#  activation_115 (Activation)  (None, 16, 16, 64)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  block0_conv0_1 (Conv2D)     (None, 8, 8, 64)          4160
#
#  batch_normalization_123 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  activation_116 (Activation)  (None, 8, 8, 64)         0
#
#  block0_conv0_2 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_124 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  activation_117 (Activation)  (None, 8, 8, 64)         0
#
#  block0_conv0_3 (Conv2D)     (None, 8, 8, 256)         16640
#
#  batch_normalization_125 (Ba  (None, 8, 8, 256)        1024
#  tchNormalization)
#
#  activation_118 (Activation)  (None, 8, 8, 256)        0
#
#  block0_conv1_1 (Conv2D)     (None, 8, 8, 64)          16448
#
#  batch_normalization_126 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  activation_119 (Activation)  (None, 8, 8, 64)         0
#
#  block0_conv1_2 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_127 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  activation_120 (Activation)  (None, 8, 8, 64)         0
#
#  block0_conv1_3 (Conv2D)     (None, 8, 8, 256)         16640
#
#  batch_normalization_128 (Ba  (None, 8, 8, 256)        1024
#  tchNormalization)
#
#  activation_121 (Activation)  (None, 8, 8, 256)        0
#
#  block0_conv2_1 (Conv2D)     (None, 8, 8, 64)          16448
#
#  batch_normalization_129 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  activation_122 (Activation)  (None, 8, 8, 64)         0
#
#  block0_conv2_2 (Conv2D)     (None, 8, 8, 64)          36928
#
#  batch_normalization_130 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  activation_123 (Activation)  (None, 8, 8, 64)         0
#
#  block0_conv2_3 (Conv2D)     (None, 8, 8, 256)         16640
#
#  batch_normalization_131 (Ba  (None, 8, 8, 256)        1024
#  tchNormalization)
#
#  activation_124 (Activation)  (None, 8, 8, 256)        0
#
#  block1_conv0_1 (Conv2D)     (None, 4, 4, 128)         32896
#
#  batch_normalization_132 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_125 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv0_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_133 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_126 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv0_3 (Conv2D)     (None, 4, 4, 512)         66048
#
#  batch_normalization_134 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_127 (Activation)  (None, 4, 4, 512)        0
#
#  block1_conv1_1 (Conv2D)     (None, 4, 4, 128)         65664
#
#  batch_normalization_135 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_128 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv1_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_136 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_129 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv1_3 (Conv2D)     (None, 4, 4, 512)         66048
#
#  batch_normalization_137 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_130 (Activation)  (None, 4, 4, 512)        0
#
#  block1_conv2_1 (Conv2D)     (None, 4, 4, 128)         65664
#
#  batch_normalization_138 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_131 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv2_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_139 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_132 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv2_3 (Conv2D)     (None, 4, 4, 512)         66048
#
#  batch_normalization_140 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_133 (Activation)  (None, 4, 4, 512)        0
#
#  block1_conv3_1 (Conv2D)     (None, 4, 4, 128)         65664
#
#  batch_normalization_141 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_134 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv3_2 (Conv2D)     (None, 4, 4, 128)         147584
#
#  batch_normalization_142 (Ba  (None, 4, 4, 128)        512
#  tchNormalization)
#
#  activation_135 (Activation)  (None, 4, 4, 128)        0
#
#  block1_conv3_3 (Conv2D)     (None, 4, 4, 512)         66048
#
#  batch_normalization_143 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_136 (Activation)  (None, 4, 4, 512)        0
#
#  block2_conv0_1 (Conv2D)     (None, 2, 2, 256)         131328
#
#  batch_normalization_144 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_137 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv0_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_145 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_138 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv0_3 (Conv2D)     (None, 2, 2, 1024)        263168
#
#  batch_normalization_146 (Ba  (None, 2, 2, 1024)       4096
#  tchNormalization)
#
#  activation_139 (Activation)  (None, 2, 2, 1024)       0
#
#  block2_conv1_1 (Conv2D)     (None, 2, 2, 256)         262400
#
#  batch_normalization_147 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_140 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv1_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_148 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_141 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv1_3 (Conv2D)     (None, 2, 2, 1024)        263168
#
#  batch_normalization_149 (Ba  (None, 2, 2, 1024)       4096
#  tchNormalization)
#
#  activation_142 (Activation)  (None, 2, 2, 1024)       0
#
#  block2_conv2_1 (Conv2D)     (None, 2, 2, 256)         262400
#
#  batch_normalization_150 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_143 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv2_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_151 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_144 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv2_3 (Conv2D)     (None, 2, 2, 1024)        263168
#
#  batch_normalization_152 (Ba  (None, 2, 2, 1024)       4096
#  tchNormalization)
#
#  activation_145 (Activation)  (None, 2, 2, 1024)       0
#
#  block2_conv3_1 (Conv2D)     (None, 2, 2, 256)         262400
#
#  batch_normalization_153 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_146 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv3_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_154 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_147 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv3_3 (Conv2D)     (None, 2, 2, 1024)        263168
#
#  batch_normalization_155 (Ba  (None, 2, 2, 1024)       4096
#  tchNormalization)
#
#  activation_148 (Activation)  (None, 2, 2, 1024)       0
#
#  block2_conv4_1 (Conv2D)     (None, 2, 2, 256)         262400
#
#  batch_normalization_156 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_149 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv4_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_157 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_150 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv4_3 (Conv2D)     (None, 2, 2, 1024)        263168
#
#  batch_normalization_158 (Ba  (None, 2, 2, 1024)       4096
#  tchNormalization)
#
#  activation_151 (Activation)  (None, 2, 2, 1024)       0
#
#  block2_conv5_1 (Conv2D)     (None, 2, 2, 256)         262400
#
#  batch_normalization_159 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_152 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv5_2 (Conv2D)     (None, 2, 2, 256)         590080
#
#  batch_normalization_160 (Ba  (None, 2, 2, 256)        1024
#  tchNormalization)
#
#  activation_153 (Activation)  (None, 2, 2, 256)        0
#
#  block2_conv5_3 (Conv2D)     (None, 2, 2, 1024)        263168
#
#  batch_normalization_161 (Ba  (None, 2, 2, 1024)       4096
#  tchNormalization)
#
#  activation_154 (Activation)  (None, 2, 2, 1024)       0
#
#  block3_conv0_1 (Conv2D)     (None, 1, 1, 512)         524800
#
#  batch_normalization_162 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_155 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv0_2 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_163 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_156 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv0_3 (Conv2D)     (None, 1, 1, 2048)        1050624
#
#  batch_normalization_164 (Ba  (None, 1, 1, 2048)       8192
#  tchNormalization)
#
#  activation_157 (Activation)  (None, 1, 1, 2048)       0
#
#  block3_conv1_1 (Conv2D)     (None, 1, 1, 512)         1049088
#
#  batch_normalization_165 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_158 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv1_2 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_166 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_159 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv1_3 (Conv2D)     (None, 1, 1, 2048)        1050624
#
#  batch_normalization_167 (Ba  (None, 1, 1, 2048)       8192
#  tchNormalization)
#
#  activation_160 (Activation)  (None, 1, 1, 2048)       0
#
#  block3_conv2_1 (Conv2D)     (None, 1, 1, 512)         1049088
#
#  batch_normalization_168 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_161 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv2_2 (Conv2D)     (None, 1, 1, 512)         2359808
#
#  batch_normalization_169 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_162 (Activation)  (None, 1, 1, 512)        0
#
#  block3_conv2_3 (Conv2D)     (None, 1, 1, 2048)        1050624
#
#  batch_normalization_170 (Ba  (None, 1, 1, 2048)       8192
#  tchNormalization)
#
#  activation_163 (Activation)  (None, 1, 1, 2048)       0
#
#  global_average_pooling2d_3   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  predictions (Dense)         (None, 10)                20490
#
# =================================================================
# Total params: 20,820,106
# Trainable params: 20,774,666
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
res_34 = build_resnet(input_shape=(224, 224, 3), is_50=False)
res_34.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 112, 112, 64)      9472
#
#  batch_normalization_171 (Ba  (None, 112, 112, 64)     256
#  tchNormalization)
#
#  activation_164 (Activation)  (None, 112, 112, 64)     0
#
#  max_pooling2d_4 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  block0_conv0_1 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_172 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_165 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv0_2 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_173 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_166 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv1_1 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_174 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_167 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv1_2 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_175 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_168 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv2_1 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_176 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_169 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv2_2 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_177 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_170 (Activation)  (None, 56, 56, 64)       0
#
#  block1_conv0_1 (Conv2D)     (None, 28, 28, 128)       73856
#
#  batch_normalization_178 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_171 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv0_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_179 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_172 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv1_1 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_180 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_173 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv1_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_181 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_174 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv2_1 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_182 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_175 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv2_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_183 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_176 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv3_1 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_184 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_177 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv3_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_185 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_178 (Activation)  (None, 28, 28, 128)      0
#
#  block2_conv0_1 (Conv2D)     (None, 14, 14, 256)       295168
#
#  batch_normalization_186 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_179 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv0_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_187 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_180 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv1_1 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_188 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_181 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv1_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_189 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_182 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv2_1 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_190 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_183 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv2_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_191 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_184 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv3_1 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_192 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_185 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv3_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_193 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_186 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv4_1 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_194 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_187 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv4_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_195 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_188 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv5_1 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_196 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_189 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv5_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_197 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_190 (Activation)  (None, 14, 14, 256)      0
#
#  block3_conv0_1 (Conv2D)     (None, 7, 7, 512)         1180160
#
#  batch_normalization_198 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_191 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv0_2 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_199 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_192 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv1_1 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_200 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_193 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv1_2 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_201 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_194 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv2_1 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_202 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_195 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv2_2 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_203 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_196 (Activation)  (None, 7, 7, 512)        0
#
#  global_average_pooling2d_4   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  predictions (Dense)         (None, 2)                 1026
#
# =================================================================
# Total params: 21,134,722
# Trainable params: 21,119,490
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
res_50 = build_resnet(input_shape=(224, 224, 3), is_50=True)
res_50.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_5 (Conv2D)           (None, 112, 112, 64)      9472
#
#  batch_normalization_204 (Ba  (None, 112, 112, 64)     256
#  tchNormalization)
#
#  activation_197 (Activation)  (None, 112, 112, 64)     0
#
#  max_pooling2d_5 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  block0_conv0_1 (Conv2D)     (None, 56, 56, 64)        4160
#
#  batch_normalization_205 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_198 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv0_2 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_206 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_199 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv0_3 (Conv2D)     (None, 56, 56, 256)       16640
#
#  batch_normalization_207 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_200 (Activation)  (None, 56, 56, 256)      0
#
#  block0_conv1_1 (Conv2D)     (None, 56, 56, 64)        16448
#
#  batch_normalization_208 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_201 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv1_2 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_209 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_202 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv1_3 (Conv2D)     (None, 56, 56, 256)       16640
#
#  batch_normalization_210 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_203 (Activation)  (None, 56, 56, 256)      0
#
#  block0_conv2_1 (Conv2D)     (None, 56, 56, 64)        16448
#
#  batch_normalization_211 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_204 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv2_2 (Conv2D)     (None, 56, 56, 64)        36928
#
#  batch_normalization_212 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_205 (Activation)  (None, 56, 56, 64)       0
#
#  block0_conv2_3 (Conv2D)     (None, 56, 56, 256)       16640
#
#  batch_normalization_213 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_206 (Activation)  (None, 56, 56, 256)      0
#
#  block1_conv0_1 (Conv2D)     (None, 28, 28, 128)       32896
#
#  batch_normalization_214 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_207 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv0_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_215 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_208 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv0_3 (Conv2D)     (None, 28, 28, 512)       66048
#
#  batch_normalization_216 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_209 (Activation)  (None, 28, 28, 512)      0
#
#  block1_conv1_1 (Conv2D)     (None, 28, 28, 128)       65664
#
#  batch_normalization_217 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_210 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv1_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_218 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_211 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv1_3 (Conv2D)     (None, 28, 28, 512)       66048
#
#  batch_normalization_219 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_212 (Activation)  (None, 28, 28, 512)      0
#
#  block1_conv2_1 (Conv2D)     (None, 28, 28, 128)       65664
#
#  batch_normalization_220 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_213 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv2_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_221 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_214 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv2_3 (Conv2D)     (None, 28, 28, 512)       66048
#
#  batch_normalization_222 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_215 (Activation)  (None, 28, 28, 512)      0
#
#  block1_conv3_1 (Conv2D)     (None, 28, 28, 128)       65664
#
#  batch_normalization_223 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_216 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv3_2 (Conv2D)     (None, 28, 28, 128)       147584
#
#  batch_normalization_224 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_217 (Activation)  (None, 28, 28, 128)      0
#
#  block1_conv3_3 (Conv2D)     (None, 28, 28, 512)       66048
#
#  batch_normalization_225 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_218 (Activation)  (None, 28, 28, 512)      0
#
#  block2_conv0_1 (Conv2D)     (None, 14, 14, 256)       131328
#
#  batch_normalization_226 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_219 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv0_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_227 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_220 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv0_3 (Conv2D)     (None, 14, 14, 1024)      263168
#
#  batch_normalization_228 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_221 (Activation)  (None, 14, 14, 1024)     0
#
#  block2_conv1_1 (Conv2D)     (None, 14, 14, 256)       262400
#
#  batch_normalization_229 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_222 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv1_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_230 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_223 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv1_3 (Conv2D)     (None, 14, 14, 1024)      263168
#
#  batch_normalization_231 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_224 (Activation)  (None, 14, 14, 1024)     0
#
#  block2_conv2_1 (Conv2D)     (None, 14, 14, 256)       262400
#
#  batch_normalization_232 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_225 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv2_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_233 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_226 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv2_3 (Conv2D)     (None, 14, 14, 1024)      263168
#
#  batch_normalization_234 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_227 (Activation)  (None, 14, 14, 1024)     0
#
#  block2_conv3_1 (Conv2D)     (None, 14, 14, 256)       262400
#
#  batch_normalization_235 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_228 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv3_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_236 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_229 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv3_3 (Conv2D)     (None, 14, 14, 1024)      263168
#
#  batch_normalization_237 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_230 (Activation)  (None, 14, 14, 1024)     0
#
#  block2_conv4_1 (Conv2D)     (None, 14, 14, 256)       262400
#
#  batch_normalization_238 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_231 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv4_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_239 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_232 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv4_3 (Conv2D)     (None, 14, 14, 1024)      263168
#
#  batch_normalization_240 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_233 (Activation)  (None, 14, 14, 1024)     0
#
#  block2_conv5_1 (Conv2D)     (None, 14, 14, 256)       262400
#
#  batch_normalization_241 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_234 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv5_2 (Conv2D)     (None, 14, 14, 256)       590080
#
#  batch_normalization_242 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_235 (Activation)  (None, 14, 14, 256)      0
#
#  block2_conv5_3 (Conv2D)     (None, 14, 14, 1024)      263168
#
#  batch_normalization_243 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_236 (Activation)  (None, 14, 14, 1024)     0
#
#  block3_conv0_1 (Conv2D)     (None, 7, 7, 512)         524800
#
#  batch_normalization_244 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_237 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv0_2 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_245 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_238 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv0_3 (Conv2D)     (None, 7, 7, 2048)        1050624
#
#  batch_normalization_246 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_239 (Activation)  (None, 7, 7, 2048)       0
#
#  block3_conv1_1 (Conv2D)     (None, 7, 7, 512)         1049088
#
#  batch_normalization_247 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_240 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv1_2 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_248 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_241 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv1_3 (Conv2D)     (None, 7, 7, 2048)        1050624
#
#  batch_normalization_249 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_242 (Activation)  (None, 7, 7, 2048)       0
#
#  block3_conv2_1 (Conv2D)     (None, 7, 7, 512)         1049088
#
#  batch_normalization_250 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_243 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv2_2 (Conv2D)     (None, 7, 7, 512)         2359808
#
#  batch_normalization_251 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_244 (Activation)  (None, 7, 7, 512)        0
#
#  block3_conv2_3 (Conv2D)     (None, 7, 7, 2048)        1050624
#
#  batch_normalization_252 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_245 (Activation)  (None, 7, 7, 2048)       0
#
#  global_average_pooling2d_5   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  predictions (Dense)         (None, 2)                 4098
#
# =================================================================
# Total params: 20,803,714
# Trainable params: 20,758,274
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# #4) ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34
# ---

# %% [markdown]
# ##Ablation Study
# <br>
#
# 이제 VGG-16, 19 예제와 같이 ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34에 대해서 학습을 진행해 봅니다. 그리고 결과를 비교해 봅시다! ResNet은 많은 레이어와 Pooling을 거치므로 CIFAR-10에서는 오버피팅(overfitting)으로 잘 동작하지 않을 수 있습니다. 레이어가 많고 학습해야 할 변수(parameter)가 많은 데 비해, 데이터 수가 많지 않기 때문이지요. 224x224 픽셀 크기의 데이터셋을 찾아서 실험해 보도록 합시다. 학습은 끝까지 시키기엔 시간이 없으니 확인을 위한 정도의 epoch로 설정해 주세요.
# <br><br>
# 어떤 데이터셋을 사용하셔도 무방하지만, 얼른 떠오르는 것이 없다면 ```tensorflow-datasets```에서 제공하는 ```cats_vs_dogs``` 데이터셋을 추천합니다. 아마 이 데이터셋도 다루어 보신 적이 있을 것입니다. Tensorflow에서 제공하는 데이터셋이므로 오늘 VGG 학습에 사용했던 CIFAR-10을 로딩하는 것과 같은 방법으로 활용하실 수 있습니다.

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
BATCH_SIZE = 256
EPOCH = 15

# %%
(ds_test, ds_train), ds_info = tfds.load("cats_vs_dogs", 
                                         split=["train[0%:20%]", "train[20%:]"],
                                         shuffle_files=True,
                                         as_supervised=True, with_info=True)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to ~/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling ~/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteNAXF9O/cats_vs_dogs-train.tfrecord*...:   0%|    …
# Dataset cats_vs_dogs downloaded and prepared to ~/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ##시각화
# <br>
#
# 학습을 통해 만들어진 ```history```를 matplotlib로 시각화하여 두 모델의 검증 정확도(validation accuracy)와 검증 손실(validation loss)이 어떻게 다른지 살펴봅시다.

# %%
resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_res_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[20%:]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[0%:20%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 72/72 [==============================] - 61s 373ms/step - loss: 0.8189 - accuracy: 0.5931 - val_loss: 0.7172 - val_accuracy: 0.5028
# Epoch 2/15
# 72/72 [==============================] - 27s 375ms/step - loss: 0.5121 - accuracy: 0.7621 - val_loss: 0.7111 - val_accuracy: 0.5302
# Epoch 3/15
# 72/72 [==============================] - 28s 392ms/step - loss: 0.3250 - accuracy: 0.8737 - val_loss: 0.7477 - val_accuracy: 0.5494
# Epoch 4/15
# 72/72 [==============================] - 27s 374ms/step - loss: 0.1836 - accuracy: 0.9385 - val_loss: 0.8115 - val_accuracy: 0.5610
# Epoch 5/15
# 72/72 [==============================] - 27s 380ms/step - loss: 0.0996 - accuracy: 0.9722 - val_loss: 0.9666 - val_accuracy: 0.5742
# Epoch 6/15
# 72/72 [==============================] - 29s 406ms/step - loss: 0.0710 - accuracy: 0.9817 - val_loss: 1.1323 - val_accuracy: 0.5635
# Epoch 7/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.0346 - accuracy: 0.9930 - val_loss: 1.3123 - val_accuracy: 0.5580
# Epoch 8/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.0274 - accuracy: 0.9939 - val_loss: 1.4313 - val_accuracy: 0.5421
# Epoch 9/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.0265 - accuracy: 0.9938 - val_loss: 1.6031 - val_accuracy: 0.5536
# Epoch 10/15
# 72/72 [==============================] - 26s 364ms/step - loss: 0.0230 - accuracy: 0.9943 - val_loss: 1.6276 - val_accuracy: 0.5588
# Epoch 11/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.0218 - accuracy: 0.9950 - val_loss: 1.6993 - val_accuracy: 0.5590
# Epoch 12/15
# 72/72 [==============================] - 26s 364ms/step - loss: 0.0182 - accuracy: 0.9952 - val_loss: 1.7500 - val_accuracy: 0.5579
# Epoch 13/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.0174 - accuracy: 0.9954 - val_loss: 1.8769 - val_accuracy: 0.5375
# Epoch 14/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.0193 - accuracy: 0.9942 - val_loss: 1.8642 - val_accuracy: 0.5612
# Epoch 15/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.0249 - accuracy: 0.9919 - val_loss: 1.9544 - val_accuracy: 0.5590

# %%
plain_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_34 = plain_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[20%:]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[0%:20%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# 72/72 [==============================] - 48s 369ms/step - loss: 1.2106 - accuracy: 0.4545 - val_loss: 1.8228 - val_accuracy: 0.4948
# Epoch 2/15
# 72/72 [==============================] - 26s 365ms/step - loss: 0.7770 - accuracy: 0.5019 - val_loss: 1.3582 - val_accuracy: 0.4899
# Epoch 3/15
# 72/72 [==============================] - 26s 366ms/step - loss: 0.7400 - accuracy: 0.5200 - val_loss: 0.9843 - val_accuracy: 0.5223
# Epoch 4/15
# 72/72 [==============================] - 27s 380ms/step - loss: 0.7288 - accuracy: 0.5120 - val_loss: 0.7984 - val_accuracy: 0.4805
# Epoch 5/15
# 72/72 [==============================] - 28s 390ms/step - loss: 0.7191 - accuracy: 0.5170 - val_loss: 0.7471 - val_accuracy: 0.5135
# Epoch 6/15
# 72/72 [==============================] - 29s 414ms/step - loss: 0.7120 - accuracy: 0.5238 - val_loss: 0.7267 - val_accuracy: 0.5000
# Epoch 7/15
# 72/72 [==============================] - 26s 360ms/step - loss: 0.7097 - accuracy: 0.5229 - val_loss: 0.7216 - val_accuracy: 0.5020
# Epoch 8/15
# 72/72 [==============================] - 26s 361ms/step - loss: 0.7085 - accuracy: 0.5203 - val_loss: 0.7181 - val_accuracy: 0.5100
# Epoch 9/15
# 72/72 [==============================] - 26s 361ms/step - loss: 0.7088 - accuracy: 0.5170 - val_loss: 0.7217 - val_accuracy: 0.5033
# Epoch 10/15
# 72/72 [==============================] - 26s 361ms/step - loss: 0.7030 - accuracy: 0.5228 - val_loss: 0.7262 - val_accuracy: 0.5223
# Epoch 11/15
# 72/72 [==============================] - 26s 360ms/step - loss: 0.7035 - accuracy: 0.5252 - val_loss: 0.7137 - val_accuracy: 0.5211
# Epoch 12/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.6969 - accuracy: 0.5299 - val_loss: 0.7239 - val_accuracy: 0.5148
# Epoch 13/15
# 72/72 [==============================] - 26s 361ms/step - loss: 0.6970 - accuracy: 0.5345 - val_loss: 0.7056 - val_accuracy: 0.5144
# Epoch 14/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.6940 - accuracy: 0.5428 - val_loss: 0.7151 - val_accuracy: 0.5127
# Epoch 15/15
# 72/72 [==============================] - 26s 365ms/step - loss: 0.6927 - accuracy: 0.5405 - val_loss: 0.7164 - val_accuracy: 0.4982

# %%
plt.plot(history_res_34.history['loss'], 'r')
plt.plot(history_plain_34.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'plainnet_34'], loc='upper left')
plt.show()

# %%
plt.plot(history_res_34.history['val_accuracy'], 'r')
plt.plot(history_plain_34.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'plainnet_34'], loc='upper left')
plt.show()

# %%
resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_res_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[20%:]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[0%:20%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# 72/72 [==============================] - 53s 375ms/step - loss: 1.0144 - accuracy: 0.5152 - val_loss: 0.7553 - val_accuracy: 0.5023
# Epoch 2/15
# 72/72 [==============================] - 27s 375ms/step - loss: 0.8745 - accuracy: 0.5339 - val_loss: 0.7576 - val_accuracy: 0.5000
# Epoch 3/15
# 72/72 [==============================] - 27s 376ms/step - loss: 0.8279 - accuracy: 0.5423 - val_loss: 0.7381 - val_accuracy: 0.5261
# Epoch 4/15
# 72/72 [==============================] - 29s 401ms/step - loss: 0.7991 - accuracy: 0.5455 - val_loss: 0.7639 - val_accuracy: 0.5278
# Epoch 5/15
# 72/72 [==============================] - 28s 391ms/step - loss: 0.7763 - accuracy: 0.5549 - val_loss: 0.8024 - val_accuracy: 0.5124
# Epoch 6/15
# 72/72 [==============================] - 26s 372ms/step - loss: 0.7640 - accuracy: 0.5581 - val_loss: 0.7735 - val_accuracy: 0.5304
# Epoch 7/15
# 72/72 [==============================] - 26s 370ms/step - loss: 0.7346 - accuracy: 0.5785 - val_loss: 0.7867 - val_accuracy: 0.5330
# Epoch 8/15
# 72/72 [==============================] - 27s 372ms/step - loss: 0.7301 - accuracy: 0.5738 - val_loss: 0.8041 - val_accuracy: 0.5243
# Epoch 9/15
# 72/72 [==============================] - 26s 371ms/step - loss: 0.7308 - accuracy: 0.5716 - val_loss: 0.8910 - val_accuracy: 0.5031
# Epoch 10/15
# 72/72 [==============================] - 26s 371ms/step - loss: 0.7311 - accuracy: 0.5722 - val_loss: 0.8139 - val_accuracy: 0.5189
# Epoch 11/15
# 72/72 [==============================] - 26s 369ms/step - loss: 0.7017 - accuracy: 0.5899 - val_loss: 0.8220 - val_accuracy: 0.5247
# Epoch 12/15
# 72/72 [==============================] - 26s 367ms/step - loss: 0.7076 - accuracy: 0.5878 - val_loss: 0.7926 - val_accuracy: 0.5280
# Epoch 13/15
# 72/72 [==============================] - 26s 370ms/step - loss: 0.6946 - accuracy: 0.5962 - val_loss: 0.7939 - val_accuracy: 0.5299
# Epoch 14/15
# 72/72 [==============================] - 27s 373ms/step - loss: 0.6921 - accuracy: 0.5940 - val_loss: 0.7897 - val_accuracy: 0.5301
# Epoch 15/15
# 72/72 [==============================] - 26s 370ms/step - loss: 0.6785 - accuracy: 0.6109 - val_loss: 0.8033 - val_accuracy: 0.5423

# %%
plain_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_50 = plain_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[20%:]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[0%:20%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 72/72 [==============================] - 51s 372ms/step - loss: 1.1304 - accuracy: 0.4580 - val_loss: 1.3459 - val_accuracy: 0.5098
# Epoch 2/15
# 72/72 [==============================] - 26s 364ms/step - loss: 0.7705 - accuracy: 0.5058 - val_loss: 0.9213 - val_accuracy: 0.5025
# Epoch 3/15
# 72/72 [==============================] - 29s 407ms/step - loss: 0.7546 - accuracy: 0.4949 - val_loss: 0.8060 - val_accuracy: 0.4900
# Epoch 4/15
# 72/72 [==============================] - 26s 371ms/step - loss: 0.7435 - accuracy: 0.5038 - val_loss: 0.7440 - val_accuracy: 0.5015
# Epoch 5/15
# 72/72 [==============================] - 27s 382ms/step - loss: 0.7353 - accuracy: 0.4993 - val_loss: 0.7256 - val_accuracy: 0.4939
# Epoch 6/15
# 72/72 [==============================] - 29s 402ms/step - loss: 0.7293 - accuracy: 0.5018 - val_loss: 0.7278 - val_accuracy: 0.4902
# Epoch 7/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.7275 - accuracy: 0.4997 - val_loss: 0.7143 - val_accuracy: 0.5152
# Epoch 8/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.7242 - accuracy: 0.4996 - val_loss: 0.7400 - val_accuracy: 0.4793
# Epoch 9/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.7215 - accuracy: 0.4992 - val_loss: 0.7416 - val_accuracy: 0.4978
# Epoch 10/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.7204 - accuracy: 0.5003 - val_loss: 0.7680 - val_accuracy: 0.5043
# Epoch 11/15
# 72/72 [==============================] - 26s 360ms/step - loss: 0.7214 - accuracy: 0.4968 - val_loss: 0.7384 - val_accuracy: 0.5013
# Epoch 12/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.7161 - accuracy: 0.5059 - val_loss: 0.7545 - val_accuracy: 0.5098
# Epoch 13/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.7172 - accuracy: 0.4952 - val_loss: 0.7237 - val_accuracy: 0.5007
# Epoch 14/15
# 72/72 [==============================] - 26s 362ms/step - loss: 0.7146 - accuracy: 0.5027 - val_loss: 0.7204 - val_accuracy: 0.5124
# Epoch 15/15
# 72/72 [==============================] - 26s 363ms/step - loss: 0.7149 - accuracy: 0.4963 - val_loss: 0.7287 - val_accuracy: 0.4955

# %%
plt.plot(history_res_50.history['loss'], 'r')
plt.plot(history_plain_50.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plainnet_50'], loc='upper left')
plt.show()

# %%
plt.plot(history_res_50.history['val_accuracy'], 'r')
plt.plot(history_plain_50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plainnet_50'], loc='upper left')
plt.show()
